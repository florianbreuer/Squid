# %%
from squid import Question_Written, Question_MCQ, selection_wizard

# %%
L = []

for a in [1,2,3]:
    for b in [1,2,3]:
        Q = Question_MCQ()
        Q.question_text = f'Compute \\({a}+{b}\\)'
        Q.answer = f'\\({a+b}\\)'
        Q.wrong_answers = [f'\\({a+b+1}\\)', f'\\({a+b+2}\\)', f'\\({a+b-1}\\)']
        L.append(Q)

# %%
L = [Question_MCQ(question_text=fr'Compute \({a}+{b}\)', 
                  answer=fr'\({a+b}\)',
                  wrong_answers=[fr'\({a+b+1}\)', fr'\({a+b+2}\)', fr'\({a+b-1}\)']
                 ) 
     for a in [1,2,3] for b in [1,2,3]
    ]

L[6]
# Out:
# Compute \(3+1\)

# %%
selection_wizard(L, course_name='Python101', question_name='StupidAdditionMCQ')
# Out:
# VBox(children=(HBox(children=(ToggleButton(value=False, description='variant 0'), HTMLMath(value=''))), HBox(c…
# HBox(children=(Button(description='Count: ', style=ButtonStyle()), Button(description='Select All', style=Butt…
# Tab(children=(VBox(children=(HBox(children=(IntRangeSlider(value=(0, 8), continuous_update=False, description=…
# Output(layout=Layout(border='1px solid black'))
# Button(description='Clear Output', style=ButtonStyle())

# %%
import matplotlib.pyplot as plt 
import numpy as np
import os

img_dir = 'images'
if not os.path.exists(img_dir):
    os.mkdir(img_dir)

# %%
def identify_crit_MCQ(a, b, s1=1, s2=1, variant_number=0):
    '''Identify the type of critical point (a,b) for f(x,y) = 1 +s1(x-a)^2 + s2(y-b)^2.
    The contour plot of f(x,y) is shown.
    Returns a Question_MCQ object.'''
    def f(x,y):
        return 1 + s1*(x-a)**2 + s2*(y-b)**2
    # create contour plot of f:
    x = np.linspace(-5, 5, 100)
    y = np.linspace(-5, 5, 100)
    X, Y = np.meshgrid(x, y)
    Z = f(X, Y)
    fig, ax = plt.subplots(figsize=(5,5))
    contours = ax.contour(X, Y, Z, 20, colors='black', linestyles='solid')
    ax.clabel(contours, inline=True, fontsize=8)
    ax.set_xticks(range(-5,6))
    ax.set_yticks(range(-5,6))
    ax.text(a+0.2, b+0.2, 'P', fontsize=10, color='red')
    ax.add_patch(plt.Circle((a,b), 0.1, color='r'))
    # Save this plot to disk:
    img_name = 'ContourPlot'+str((s1,s2))+'_'+str((a,b))+'.png'
    img_path = os.path.join(img_dir, img_name)
    fig.savefig(img_path, transparent=False, dpi=160, bbox_inches="tight")
    # now write question and answers:
    Q = Question_MCQ()
    Q.marks = 2
    # the question text is simple html:
    Q.question_text = fr'''<img src="{img_path}" width="50%"><br>
            Classify the critical point at \(P = {(a,b)}\) of the function \(f(x,y)\) whose 
            contour plot is shown above.'''
    if s1*s2 < 0:
        Q.answer = 'Saddle point'
    elif s1 < 0:
        Q.answer = 'Local maximum'
    else: 
        Q.answer = 'Local minimum'
    Q.wrong_answers = ['Saddle point', 'Local maximum', 'Local minimum', 'Inflection point']
    Q.wrong_answers.remove(Q.answer)
    return Q

Q = identify_crit_MCQ(2,1,-2)

# %%
Q
# Out:
# <img src="images/ContourPlot(-2, 1)_(2, 1).png" width="50%"><br>
#             Classify the critical point at \(P = (2, 1)\) of the function \(f(x,y)\) whose
#             contour plot is shown above.

# %%
ordering = random.sample(ordering[:-1], len(ordering[:-1]))+[ordering[-1]]
ordering
# Out:
# [8, 6, 1, 2, 5, 7, 0, 4, 3, 9]

# %%
dir()
# Out:
# ['In',
#  'L',
#  'Out',
#  'Q',
#  'Question_MCQ',
#  'Question_Written',
#  '_',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  '_sh',
#  'a',
#  'b',
#  'exit',
#  'get_ipython',
#  'quit',
#  'selection_wizard']

# %%
load?
